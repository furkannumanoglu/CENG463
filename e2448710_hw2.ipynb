# %%
# 1. Loading
# !pip install transformers datasets torch pandas scikit-learn bitsandbytes -q

# 2. Importing libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from transformers import (
    AutoModelForSequenceClassification,
    AutoTokenizer,
    TrainingArguments,
    Trainer,
    pipeline
)
from datasets import Dataset
import torch

# 3. GPU control
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device: {device}")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 31.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 28.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 14.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Device: cuda

# %%
# 4. Analyze and load datasets
def load_and_analyze_data(file_path, task_name):
    df = pd.read_csv(file_path, sep='\t')
    print(f"\n{task_name} dataset analysis:")
    print(f"Total sample number: {len(df)}")
    print(f"Labels:\n{df['label'].value_counts()}")
    return df

orientation_df = load_and_analyze_data('orientation-tr-train.tsv', 'Ideology')
power_df = load_and_analyze_data('power-tr-train.tsv', 'Power')
# Out:
# Ideology dataset analysis:
# Total sample number: 16138
# Labels:
# label
# 1    9390
# 0    6748
# Name: count, dtype: int64
#
# Power dataset analysis:
# Total sample number: 17384
# Labels:
# label
# 1    8932
# 0    8452
# Name: count, dtype: int64

# %%
# 5. 90-10 stratified split
def split_data(df, task_name):
    print(f"\n{task_name} - Before splitting:")
    print(df['label'].value_counts(normalize=True))

    train_data, val_data = train_test_split(
        df,
        test_size=0.1,
        stratify=df['label'],
        random_state=42
    )

    print(f"\n{task_name} - After splitting on training set:")
    print(train_data['label'].value_counts(normalize=True))
    print(f"\n{task_name} - After splitting on validation set")
    print(val_data['label'].value_counts(normalize=True))


    print(f"\nTrain set size: {len(train_data)}")
    print(f"Validation set size: {len(val_data)}")

    return train_data, val_data

orientation_train, orientation_val = split_data(orientation_df, "Ideology")
power_train, power_val = split_data(power_df, "Power")
# Out:
# Ideology - Before splitting:
# label
# 1    0.581856
# 0    0.418144
# Name: proportion, dtype: float64
#
# Ideology - After splitting on training set:
# label
# 1    0.581865
# 0    0.418135
# Name: proportion, dtype: float64
#
# Ideology - After splitting on validation set
# label
# 1    0.581784
# 0    0.418216
# Name: proportion, dtype: float64
#
# Train set size: 14524
# Validation set size: 1614
#
# Power - Before splitting:
# label
# 1    0.513806
# 0    0.486194
# Name: proportion, dtype: float64
#
# Power - After splitting on training set:
# label
# 1    0.513774
# 0    0.486226
# Name: proportion, dtype: float64
#
# Power - After splitting on validation set
# label
# 1    0.514089
# 0    0.485911
# Name: proportion, dtype: float64
#
# Train set size: 15645
# Validation set size: 1739

# %%
MODEL_NAME = "xlm-roberta-base"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

def prepare_dataset(df, text_column, max_length=128):
    dataset = Dataset.from_pandas(df)

    def tokenize_function(examples):
        return tokenizer(
            examples[text_column],
            padding='max_length',
            truncation=True,
            max_length=max_length
        )

    tokenized_dataset = dataset.map(tokenize_function, batched=True)
    tokenized_dataset = tokenized_dataset.remove_columns(
        [col for col in tokenized_dataset.column_names
         if col not in ['input_ids', 'attention_mask', 'label']]
    )
    return tokenized_dataset
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)

    accuracy = accuracy_score(labels, preds)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='binary')

    metrics = {
        'accuracy': accuracy,
        'f1': f1,
        'precision': precision,
        'recall': recall
    }

    print(f"\nCurrent metrics: {metrics}")
    return metrics

def train_model(train_dataset, val_dataset, task_name, output_dir):
    model = AutoModelForSequenceClassification.from_pretrained(
        MODEL_NAME,
        num_labels=2
    ).to(device)

    training_args = TrainingArguments(
        output_dir=output_dir,
        num_train_epochs=10,
        per_device_train_batch_size=8,
        per_device_eval_batch_size=8,
        warmup_ratio=0.1,
        learning_rate=1e-5,
        weight_decay=0.05,
        #evaluation_strategy="steps",
        evaluation_strategy="epoch",
        #eval_steps=500,
        #save_strategy="steps",
        save_strategy="epoch",
        #save_steps=500,
        load_best_model_at_end=True,
        metric_for_best_model="f1",
        greater_is_better=True
    )

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=val_dataset,
        compute_metrics=compute_metrics
    )

    print(f"\n{task_name} model training is starting...")
    train_result = trainer.train()

    print(f"\n{task_name} Final Training Metrics:")
    print(train_result.metrics)

    return trainer, model

# %%
# 8. Task 1: (English)
orientation_train_dataset = prepare_dataset(orientation_train, 'text_en')
orientation_val_dataset = prepare_dataset(orientation_val, 'text_en')

orientation_trainer, orientation_model = train_model(
    orientation_train_dataset,
    orientation_val_dataset,
    "Ideology",
    "./ideology_model"
)
# Out:
# Map:   0%|          | 0/14524 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1614 [00:00<?, ? examples/s]
# model.safetensors:   0%|          | 0.00/1.12G [00:00<?, ?B/s]
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# Ideology model training is starting...
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/content/wandb/run-20250104_011604-8b38ingj</code>
# Syncing run <strong><a href='https://wandb.ai/furkannumanoglu07-metu-middle-east-technical-university/huggingface/runs/8b38ingj' target="_blank">./ideology_model</a></strong> to <a href='https://wandb.ai/furkannumanoglu07-metu-middle-east-technical-university/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/furkannumanoglu07-metu-middle-east-technical-university/huggingface' target="_blank">https://wandb.ai/furkannumanoglu07-metu-middle-east-technical-university/huggingface</a>
#  View run at <a href='https://wandb.ai/furkannumanoglu07-metu-middle-east-technical-university/huggingface/runs/8b38ingj' target="_blank">https://wandb.ai/furkannumanoglu07-metu-middle-east-technical-university/huggingface/runs/8b38ingj</a>
#     <div>
#
#       <progress value='18160' max='18160' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18160/18160 1:31:21, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.556900</td>
#       <td>0.470242</td>
#       <td>0.781289</td>
#       <td>0.806150</td>
#       <td>0.832200</td>
#       <td>0.781683</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.449300</td>
#       <td>0.426392</td>
#       <td>0.796778</td>
#       <td>0.816555</td>
#       <td>0.859835</td>
#       <td>0.777423</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.363800</td>
#       <td>0.440706</td>
#       <td>0.814126</td>
#       <td>0.841438</td>
#       <td>0.835257</td>
#       <td>0.847710</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.347400</td>
#       <td>0.599236</td>
#       <td>0.806691</td>
#       <td>0.831715</td>
#       <td>0.842623</td>
#       <td>0.821086</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.289300</td>
#       <td>0.862540</td>
#       <td>0.801115</td>
#       <td>0.838450</td>
#       <td>0.794847</td>
#       <td>0.887114</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.222700</td>
#       <td>0.964111</td>
#       <td>0.809170</td>
#       <td>0.830583</td>
#       <td>0.858931</td>
#       <td>0.804047</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.179100</td>
#       <td>0.976304</td>
#       <td>0.819083</td>
#       <td>0.845175</td>
#       <td>0.841605</td>
#       <td>0.848775</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.116700</td>
#       <td>1.218286</td>
#       <td>0.808550</td>
#       <td>0.827084</td>
#       <td>0.871462</td>
#       <td>0.787007</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.095800</td>
#       <td>1.304395</td>
#       <td>0.802354</td>
#       <td>0.823854</td>
#       <td>0.855505</td>
#       <td>0.794462</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.075100</td>
#       <td>1.406269</td>
#       <td>0.800496</td>
#       <td>0.827438</td>
#       <td>0.832794</td>
#       <td>0.822151</td>
#     </tr>
#   </tbody>
# </table><p>
# Current metrics: {'accuracy': 0.7812887236679058, 'f1': 0.8061504667764964, 'precision': 0.8321995464852607, 'recall': 0.7816826411075612}
#
# Current metrics: {'accuracy': 0.7967781908302355, 'f1': 0.8165548098434005, 'precision': 0.8598351001177856, 'recall': 0.777422790202343}
#
# Current metrics: {'accuracy': 0.8141263940520446, 'f1': 0.8414376321353065, 'precision': 0.8352570828961176, 'recall': 0.8477103301384451}
#
# Current metrics: {'accuracy': 0.8066914498141264, 'f1': 0.8317152103559871, 'precision': 0.8426229508196721, 'recall': 0.8210862619808307}
#
# Current metrics: {'accuracy': 0.8011152416356877, 'f1': 0.8384499245093106, 'precision': 0.7948473282442748, 'recall': 0.8871139510117146}
#
# Current metrics: {'accuracy': 0.8091697645600991, 'f1': 0.8305830583058306, 'precision': 0.8589306029579067, 'recall': 0.8040468583599574}
#
# Current metrics: {'accuracy': 0.8190830235439901, 'f1': 0.8451749734888653, 'precision': 0.8416050686378036, 'recall': 0.8487752928647497}
#
# Current metrics: {'accuracy': 0.8085501858736059, 'f1': 0.8270844991606043, 'precision': 0.8714622641509434, 'recall': 0.7870074547390842}
#
# Current metrics: {'accuracy': 0.8023543990086741, 'f1': 0.8238542241855329, 'precision': 0.8555045871559633, 'recall': 0.7944621938232161}
#
# Current metrics: {'accuracy': 0.8004956629491945, 'f1': 0.827438370846731, 'precision': 0.8327939590075513, 'recall': 0.8221512247071352}
#
# Ideology Final Training Metrics:
# {'train_runtime': 5551.4279, 'train_samples_per_second': 26.163, 'train_steps_per_second': 3.271, 'total_flos': 9553562420121600.0, 'train_loss': 0.27185635866047525, 'epoch': 10.0}

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# 9. Task 2: (Turkish)
power_train_dataset = prepare_dataset(power_train, 'text')
power_val_dataset = prepare_dataset(power_val, 'text')

power_trainer, power_model = train_model(
    power_train_dataset,
    power_val_dataset,
    "Power",
    "./power_model"
)
# Out:
# Map:   0%|          | 0/15645 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1739 [00:00<?, ? examples/s]
# model.safetensors:   0%|          | 0.00/1.12G [00:00<?, ?B/s]
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# Power model training is starting...
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/content/wandb/run-20250104_080317-602lqv72</code>
# Syncing run <strong><a href='https://wandb.ai/furkannumanoglu07-metu-middle-east-technical-university/huggingface/runs/602lqv72' target="_blank">./power_model</a></strong> to <a href='https://wandb.ai/furkannumanoglu07-metu-middle-east-technical-university/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/furkannumanoglu07-metu-middle-east-technical-university/huggingface' target="_blank">https://wandb.ai/furkannumanoglu07-metu-middle-east-technical-university/huggingface</a>
#  View run at <a href='https://wandb.ai/furkannumanoglu07-metu-middle-east-technical-university/huggingface/runs/602lqv72' target="_blank">https://wandb.ai/furkannumanoglu07-metu-middle-east-technical-university/huggingface/runs/602lqv72</a>
#     <div>
#
#       <progress value='19560' max='19560' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [19560/19560 1:46:48, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
from huggingface_hub import login
import torch
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

login("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")

def zero_shot_inference():
    model_name = "meta-llama/Llama-3.1-8B"

    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        device_map="auto",
        torch_dtype=torch.float16,
        load_in_4bit=True
    )
    tokenizer = AutoTokenizer.from_pretrained(model_name)

    pipe = pipeline(
        "text-generation",
        model=model,
        tokenizer=tokenizer,
        device_map="auto",
        max_new_tokens=1,
        temperature=0.01,
        pad_token_id=tokenizer.eos_token_id,
        batch_size=1
    )

    def process_batch(texts, task_type, batch_size=16):
        results = []
        template = "You are an AI analyzing political speeches.\nSpeech: {}\nQuestion: Is the speaker from {} (0) or {} (1)?\nAnswer only with 0 or 1:"
        options = {
            "ideology": ("left-wing", "right-wing"),
            "power": ("government", "opposition")
        }

        for i in range(0, len(texts), batch_size):
            batch = texts[i:i + batch_size]
            for text in batch:
                try:
                    prompt = template.format(text[:256], *options[task_type])
                    output = pipe(prompt)[0]['generated_text']
                    last_num = next((c for c in reversed(output) if c in '01'), '0')
                    results.append(int(last_num))
                except Exception as e:
                    print(f"Error: {str(e)[:100]}")
                    results.append(0)
            print(f"Processed {i+len(batch)}/{len(texts)}")
        return results

    results = {
        'ideology': {
            'en': process_batch(orientation_val['text_en'].tolist(), 'ideology'),
            'original': process_batch(orientation_val['text'].tolist(), 'ideology')
        },
        'power': {
            'en': process_batch(power_val['text_en'].tolist(), 'power'),
            'original': process_batch(power_val['text'].tolist(), 'power')
        }
    }

    print("\nZero-shot Results:")
    for task in results:
        for lang in results[task]:
            true_labels = orientation_val['label'].tolist() if task == 'ideology' else power_val['label'].tolist()
            pred_labels = results[task][lang]

            metrics = precision_recall_fscore_support(true_labels, pred_labels, average='binary')
            acc = accuracy_score(true_labels, pred_labels)

            print(f"\n{task.upper()} - {lang}")
            print(f"Accuracy: {acc:.3f}")
            print(f"F1/Precision/Recall: {metrics[2]:.3f}/{metrics[0]:.3f}/{metrics[1]:.3f}")

    return results

results = zero_shot_inference()
# Out:
# config.json:   0%|          | 0.00/826 [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Device set to use cuda:0
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/nn/modules.py:451: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_dtype=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Processed 16/1614
# Processed 32/1614
# Processed 48/1614
# Processed 64/1614
# Processed 80/1614
# Processed 96/1614
# Processed 112/1614
# Processed 128/1614
# Processed 144/1614
# Processed 160/1614
# Processed 176/1614
# Processed 192/1614
# Processed 208/1614
# Processed 224/1614
# Processed 240/1614
# Processed 256/1614
# Processed 272/1614
# Processed 288/1614
# Processed 304/1614
# Processed 320/1614
# Processed 336/1614
# Processed 352/1614
# Processed 368/1614
# Processed 384/1614
# Processed 400/1614
# Processed 416/1614
# Processed 432/1614
# Processed 448/1614
# Processed 464/1614
# Processed 480/1614
# Processed 496/1614
# Processed 512/1614
# Processed 528/1614
# Processed 544/1614
# Processed 560/1614
# Processed 576/1614
# Processed 592/1614
# Processed 608/1614
# Processed 624/1614
# Processed 640/1614
# Processed 656/1614
# Processed 672/1614
# Processed 688/1614
# Processed 704/1614
# Processed 720/1614
# Processed 736/1614
# Processed 752/1614
# Processed 768/1614
# Processed 784/1614
# Processed 480/1739
# Processed 496/1739
# Processed 512/1739
# Processed 528/1739
# Processed 544/1739
# Processed 560/1739
# Processed 576/1739
# Processed 592/1739
# Processed 608/1739
# Processed 624/1739
# Processed 640/1739
# Processed 656/1739
# Processed 672/1739
# Processed 688/1739
# Processed 704/1739
# Processed 720/1739
# Processed 736/1739
# Processed 752/1739
# Processed 768/1739
# Processed 784/1739
# Processed 800/1739
# Processed 816/1739
# Processed 832/1739
# Processed 848/1739
# Processed 864/1739
# Processed 880/1739
# Processed 896/1739
# Processed 912/1739
# Processed 928/1739
# Processed 944/1739
# Processed 960/1739
# Processed 976/1739
# Processed 992/1739
# Processed 1008/1739
# Processed 1024/1739
# Processed 1040/1739
# Processed 1056/1739
# Processed 1072/1739
# Processed 1088/1739
# Processed 1104/1739
# Processed 1120/1739
# Processed 1136/1739
# Processed 1152/1739
# Processed 1168/1739
# Processed 1184/1739
# Processed 1200/1739
# Processed 1216/1739
# Processed 1232/1739
# Processed 1248/1739
# Processed 1264/1739
# Processed 1280/1739
# Processed 1296/1739
# Processed 1312/1739
# Processed 1328/1739
# Processed 1344/1739
# Processed 1360/1739
# Processed 1376/1739
# Processed 1392/1739
# Processed 1408/1739
# Processed 1424/1739
# Processed 1440/1739
# Processed 1456/1739
# Processed 1472/1739
# Processed 1488/1739
# Processed 1504/1739
# Processed 1520/1739
# Processed 1536/1739
# Processed 1552/1739
# Processed 1568/1739
# Processed 1584/1739
# Processed 1600/1739
# Processed 1616/1739
# Processed 1632/1739
# Processed 1648/1739
# Processed 1664/1739
# Processed 1680/1739
# Processed 1696/1739
# Processed 1712/1739
# Processed 1728/1739
# Processed 1739/1739
#
# Zero-shot Results:
#
# IDEOLOGY - en
# Accuracy: 0.582
# F1/Precision/Recall: 0.736/0.582/1.000
#
# IDEOLOGY - original
# Accuracy: 0.582
# F1/Precision/Recall: 0.736/0.582/1.000
#
# POWER - en
# Accuracy: 0.514
# F1/Precision/Recall: 0.679/0.514/1.000
#
# POWER - original
# Accuracy: 0.514
# F1/Precision/Recall: 0.679/0.514/1.000

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
from huggingface_hub import login
import torch
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, f1_score, precision_score, recall_score

login("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")


def create_optimized_prompt(text, task_type):
    if task_type == "ideology":
        prompt = """Analyze this parliamentary speech for political ideology classification.

Speech: {text}

Consider these aspects:
- Economic policy positions
- Social policy stances
- State intervention views
- Cultural and traditional values
- References to specific political concepts

Based on these indicators, is this speech from a:
- Left-wing politician (0): Focus on social welfare, equality, state intervention
- Right-wing politician (1): Focus on traditional values, free market, conservative policies

Output only 0 or 1."""

    else:
        prompt = """Analyze this parliamentary speech for power position classification.

Speech: {text}

Consider these aspects:
- Tone towards current policies
- Criticism or support of government actions
- Discussion of implementation vs opposition
- References to governance responsibilities
- Legislative agenda stance

Based on these indicators, is this speech from a:
- Government party member (0): Implementation focus, policy defense
- Opposition party member (1): Policy criticism, alternative proposals

Output only 0 or 1."""

    return prompt.format(text=text[:1000])

def zero_shot_inference():
    model_name = "meta-llama/Llama-3.1-8B"

    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        device_map="auto",
        torch_dtype=torch.float16,
        load_in_4bit=True
    )
    tokenizer = AutoTokenizer.from_pretrained(model_name)

    pipe = pipeline(
        "text-generation",
        model=model,
        tokenizer=tokenizer,
        device_map="auto",
        max_new_tokens=1,
        temperature=0.1,
        top_p=0.9,
        do_sample=True,
        pad_token_id=tokenizer.eos_token_id,
    )

    def process_batch(texts, task_type, batch_size=8):
        results = []

        for i in range(0, len(texts), batch_size):
            batch = texts[i:i + batch_size]
            batch_prompts = [create_optimized_prompt(text, task_type) for text in batch]

            try:
                outputs = pipe(batch_prompts)
                for output in outputs:
                    prediction = int(output[0]['generated_text'][-1]) if output[0]['generated_text'][-1] in ['0', '1'] else 0
                    results.append(prediction)

            except Exception as e:
                print(f"Error in batch processing: {str(e)[:100]}")
                results.extend([0] * len(batch))

            print(f"Processed {i+len(batch)}/{len(texts)} examples")

        return results

    def evaluate_results(predictions, true_labels):
        accuracy = accuracy_score(true_labels, predictions)
        f1 = f1_score(true_labels, predictions, average='weighted')
        precision = precision_score(true_labels, predictions, average='weighted')
        recall = recall_score(true_labels, predictions, average='weighted')

        return {
            'accuracy': accuracy,
            'f1': f1,
            'precision': precision,
            'recall': recall
        }

    results = {
        'ideology': {
            'en': process_batch(orientation_val['text_en'].tolist(), 'ideology'),
            'original': process_batch(orientation_val['text'].tolist(), 'ideology')
        },
        'power': {
            'en': process_batch(power_val['text_en'].tolist(), 'power'),
            'original': process_batch(power_val['text'].tolist(), 'power')
        }
    }


    return results

results = zero_shot_inference()
# Out:
# config.json:   0%|          | 0.00/826 [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Device set to use cuda:0
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/nn/modules.py:451: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_dtype=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(
# Processed 8/1614 examples
# Processed 16/1614 examples
# Processed 24/1614 examples
# Processed 32/1614 examples
# Processed 40/1614 examples
# Processed 48/1614 examples
# Processed 56/1614 examples
# Processed 64/1614 examples
# Processed 72/1614 examples
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Processed 80/1614 examples
# Processed 88/1614 examples
# Processed 96/1614 examples
# Processed 104/1614 examples
# Processed 112/1614 examples
# Processed 120/1614 examples
# Processed 128/1614 examples
# Processed 136/1614 examples
# Processed 144/1614 examples
# Processed 152/1614 examples
# Processed 160/1614 examples
# Processed 168/1614 examples
# Processed 176/1614 examples
# Processed 184/1614 examples
# Processed 192/1614 examples
# Processed 200/1614 examples
# Processed 208/1614 examples
# Processed 216/1614 examples
# Processed 224/1614 examples
# Processed 232/1614 examples
# Processed 240/1614 examples
# Processed 248/1614 examples
# Processed 256/1614 examples
# Processed 264/1614 examples
# Processed 272/1614 examples
# Processed 280/1614 examples
# Processed 288/1614 examples
# Processed 296/1614 examples
# Processed 304/1614 examples
# Processed 312/1614 examples
# Processed 320/1614 examples
# Processed 328/1614 examples
# Processed 336/1614 examples
# Processed 344/1614 examples
# Processed 352/1614 examples
# Processed 360/1614 examples
# Processed 368/1614 examples
# Processed 376/1614 examples
# Processed 384/1614 examples
# Processed 392/1614 examples
# Processed 400/1614 examples
# Processed 408/1614 examples
# Processed 416/1614 examples
# Processed 424/1614 examples
# Processed 432/1614 examples
# Processed 440/1614 examples
# Processed 448/1614 examples
# Processed 456/1614 examples
        recall = recall_score(true_labels, predictions, average='weighted')

        return {
            'accuracy': accuracy,
            'f1': f1,
            'precision': precision,
            'recall': recall
        }

print("\nZero-shot Results:")
for task in results:
    for lang in results[task]:
        true_labels = orientation_val['label'].tolist() if task == 'ideology' else power_val['label'].tolist()
        metrics = evaluate_results2(results[task][lang], true_labels)

        print(f"\n{task.upper()} - {lang}")
        print(f"Accuracy: {metrics['accuracy']:.3f}")
        print(f"F1/Precision/Recall: {metrics['f1']:.3f}/{metrics['precision']:.3f}/{metrics['recall']:.3f}")
# Out:
# Zero-shot Results:
#
# IDEOLOGY - en
# Accuracy: 0.418
# F1/Precision/Recall: 0.247/0.175/0.418
#
# IDEOLOGY - original
# Accuracy: 0.418
# F1/Precision/Recall: 0.247/0.175/0.418
#
# POWER - en
# Accuracy: 0.486
# F1/Precision/Recall: 0.318/0.236/0.486
#
# POWER - original
# Accuracy: 0.486
# F1/Precision/Recall: 0.318/0.236/0.486
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
from huggingface_hub import login
import torch
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
import numpy as np

login("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")


def create_optimized_prompt(text, task_type):
    """Create an optimized prompt for the specific task"""
    if task_type == "ideology":
        prompt = """Analyze this parliamentary speech and determine if it represents left-wing (0) or right-wing (1) political ideology.
Speech: {text}
Output only 0 or 1:"""
    else:  # power classification
        prompt = """Analyze this parliamentary speech and determine if it's from a government party member (0) or opposition party member (1).
Speech: {text}
Output only 0 or 1:"""

    return prompt.format(text=text[:512])

def run_zero_shot_inference(orientation_val, power_val, model_name="meta-llama/Llama-3.1-8B"):
    """Run zero-shot inference using Llama model"""

    print("\nLoading model...")
    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        device_map="auto",
        torch_dtype=torch.float16,
        load_in_4bit=True
    )
    tokenizer = AutoTokenizer.from_pretrained(model_name, padding_side='left')
    tokenizer.pad_token = tokenizer.eos_token

    pipe = pipeline(
        "text-generation",
        model=model,
        tokenizer=tokenizer,
        device_map="auto",
        max_new_tokens=10,
        temperature=0.9,
        top_p=0.9,
        do_sample=True,
        batch_size=8
    )

    def process_batch(texts, true_labels, task_type, batch_size=8, metric_interval=32):
        """Process texts in batches with intermediate metrics"""
        results = []

        for i in range(0, len(texts), batch_size):
            batch = texts[i:i + batch_size]
            batch_prompts = [create_optimized_prompt(text, task_type) for text in batch]

            try:
                with torch.no_grad():
                    outputs = pipe(batch_prompts)
                    for output in outputs:
                        last_char = output[0]['generated_text'].strip()[-1]
                        pred = int(last_char) if last_char in ['0', '1'] else 0
                        results.append(pred)
            except Exception as e:
                print(f"Error in batch {i}: {str(e)[:100]}")
                results.extend([0] * len(batch))

            if len(results) % metric_interval == 0:
                current_preds = np.array(results)
                current_true = true_labels[:len(results)]

                current_metrics = {
                    'accuracy': accuracy_score(current_true, current_preds),
                    'f1': f1_score(current_true, current_preds, average='weighted'),
                    'precision': precision_score(current_true, current_preds, average='weighted'),
                    'recall': recall_score(current_true, current_preds, average='weighted')
                }

                print(f"\nIntermediate Results ({len(results)}/{len(texts)} examples):")
                print(f"Accuracy: {current_metrics['accuracy']:.3f}")
                print(f"F1: {current_metrics['f1']:.3f}")
                print(f"Precision: {current_metrics['precision']:.3f}")
                print(f"Recall: {current_metrics['recall']:.3f}")

        return results

    results = {}
    tasks = {
        'ideology': orientation_val,
        'power': power_val
    }

    for task_name, val_data in tasks.items():
        results[task_name] = {}

        for text_field in ['text_en', 'text']:
            print(f"\nProcessing {task_name} - {text_field}")
            predictions = process_batch(
                texts=val_data[text_field].tolist(),
                true_labels=val_data['label'].values,
                task_type=task_name,
                batch_size=8,
                metric_interval=32
            )

            true_labels = val_data['label'].values
            metrics = {
                'accuracy': accuracy_score(true_labels, predictions),
                'f1': f1_score(true_labels, predictions, average='weighted'),
                'precision': precision_score(true_labels, predictions, average='weighted'),
                'recall': recall_score(true_labels, predictions, average='weighted')
            }

            results[task_name][text_field] = {
                'predictions': predictions,
                'metrics': metrics
            }

            print(f"\nFinal Results for {task_name} using {text_field}:")
            print(f"Accuracy: {metrics['accuracy']:.3f}")
            print(f"F1: {metrics['f1']:.3f}")
            print(f"Precision: {metrics['precision']:.3f}")
            print(f"Recall: {metrics['recall']:.3f}")

    return results

results = run_zero_shot_inference(orientation_val, power_val)
# Out:
# Loading model...
# config.json:   0%|          | 0.00/826 [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Device set to use cuda:0
# Processing ideology - text_en
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/nn/modules.py:451: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_dtype=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(
# Intermediate Results (32/1614 examples):
# Accuracy: 0.438
# F1: 0.402
# Precision: 0.681
# Recall: 0.438
#
# Intermediate Results (64/1614 examples):
# Accuracy: 0.359
# F1: 0.302
# Precision: 0.389
# Recall: 0.359
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Intermediate Results (96/1614 examples):
# Accuracy: 0.438
# F1: 0.381
# Precision: 0.466
# Recall: 0.438
#
# Intermediate Results (128/1614 examples):
# Accuracy: 0.430
# F1: 0.360
# Precision: 0.464
# Recall: 0.430
#
# Intermediate Results (160/1614 examples):
# Accuracy: 0.412
# F1: 0.342
# Precision: 0.481
# Recall: 0.412
#
# Intermediate Results (192/1614 examples):
# Accuracy: 0.432
# F1: 0.370
# Precision: 0.498
# Recall: 0.432
#
# Intermediate Results (224/1614 examples):
# Accuracy: 0.424
# F1: 0.358
# Precision: 0.501
# Recall: 0.424
#
# Intermediate Results (256/1614 examples):
# Accuracy: 0.418
# F1: 0.354
# Precision: 0.485
# Recall: 0.418
#
# Intermediate Results (288/1614 examples):
# Accuracy: 0.438
# F1: 0.371
# Precision: 0.490
# Recall: 0.438
#
# Intermediate Results (320/1614 examples):
# Accuracy: 0.459
# F1: 0.398
# Precision: 0.514
# Recall: 0.459
#
# Intermediate Results (352/1614 examples):
# Accuracy: 0.449
# F1: 0.384
# Precision: 0.519
# Recall: 0.449
#
# Intermediate Results (384/1614 examples):
# Accuracy: 0.451
# F1: 0.386
# Precision: 0.515
# Recall: 0.451
#
# Intermediate Results (416/1614 examples):
# Accuracy: 0.454
# F1: 0.392
# Precision: 0.528
# Recall: 0.454
#
# Intermediate Results (448/1614 examples):
# Accuracy: 0.455
# F1: 0.394
# Precision: 0.527
# Recall: 0.455
#
# Intermediate Results (480/1614 examples):
# Accuracy: 0.452
# F1: 0.392
# Precision: 0.540
# Recall: 0.452
#
# Intermediate Results (512/1614 examples):
# Accuracy: 0.443
# F1: 0.380
# Precision: 0.529
# Recall: 0.443
#
# Intermediate Results (544/1614 examples):
# Accuracy: 0.443
# F1: 0.379
# Precision: 0.533
# Recall: 0.443
#
# Intermediate Results (576/1614 examples):
# Accuracy: 0.444
# F1: 0.377
# Precision: 0.536
# Recall: 0.444
#
# Intermediate Results (608/1614 examples):
# Accuracy: 0.446
# F1: 0.381
# Precision: 0.547
# Recall: 0.446
#
# Intermediate Results (640/1614 examples):
# Accuracy: 0.455
# F1: 0.389
# Precision: 0.555
# Recall: 0.455
#
# Intermediate Results (672/1614 examples):
# Accuracy: 0.452
# F1: 0.384
# Precision: 0.553
# Recall: 0.452
#
# Intermediate Results (704/1614 examples):
# Accuracy: 0.455
# F1: 0.386
# Precision: 0.562
# Recall: 0.455
#
# Intermediate Results (736/1614 examples):
# Accuracy: 0.458
# F1: 0.388
# Precision: 0.554
# Recall: 0.458
#
# Intermediate Results (768/1614 examples):
# Accuracy: 0.456
# F1: 0.384
# Precision: 0.550
# Recall: 0.456
#
# Intermediate Results (800/1614 examples):
# Accuracy: 0.455
# F1: 0.385
# Precision: 0.552
# Recall: 0.455
#
# Intermediate Results (832/1614 examples):
# Accuracy: 0.456
# F1: 0.386
# Precision: 0.548
# Recall: 0.456
#
# Intermediate Results (864/1614 examples):
# Accuracy: 0.458
# F1: 0.388
# Precision: 0.550
# Recall: 0.458
#
# Intermediate Results (896/1614 examples):
# Accuracy: 0.459
# F1: 0.389
# Precision: 0.555
# Recall: 0.459
#
# Intermediate Results (928/1614 examples):
# Accuracy: 0.459
# F1: 0.391
# Precision: 0.554
# Recall: 0.459
#
# Intermediate Results (960/1614 examples):
# Accuracy: 0.450
# F1: 0.381
# Precision: 0.541
# Recall: 0.450
#
# Intermediate Results (992/1614 examples):
# Accuracy: 0.450
# F1: 0.381
# Precision: 0.547
# Recall: 0.450
#
# Intermediate Results (1024/1614 examples):
# Accuracy: 0.447
# F1: 0.377
# Precision: 0.544
# Recall: 0.447
#
# Intermediate Results (1056/1614 examples):
# Accuracy: 0.448
# F1: 0.376
# Precision: 0.547
# Recall: 0.448
#
# Intermediate Results (1088/1614 examples):
# Accuracy: 0.449
# F1: 0.377
# Precision: 0.552
# Recall: 0.449
#
# Intermediate Results (1120/1614 examples):
# Accuracy: 0.454
# F1: 0.382
# Precision: 0.553
# Recall: 0.454
#
# Intermediate Results (1152/1614 examples):
# Accuracy: 0.455
# F1: 0.382
# Precision: 0.551
# Recall: 0.455
#
# Intermediate Results (1184/1614 examples):
# Accuracy: 0.454
# F1: 0.380
# Precision: 0.553
# Recall: 0.454
#
# Intermediate Results (1216/1614 examples):
# Accuracy: 0.454
# F1: 0.383
# Precision: 0.551
# Recall: 0.454
#
# Intermediate Results (1248/1614 examples):
# Accuracy: 0.457
# F1: 0.387
# Precision: 0.551
# Recall: 0.457
#
# Intermediate Results (1280/1614 examples):
# Accuracy: 0.453
# F1: 0.384
# Precision: 0.553
# Recall: 0.453
#
# Intermediate Results (1312/1614 examples):
# Accuracy: 0.454
# F1: 0.385
# Precision: 0.550
# Recall: 0.454
#
# Intermediate Results (1344/1614 examples):
# Accuracy: 0.455
# F1: 0.385
# Precision: 0.549
# Recall: 0.455
#
# Intermediate Results (1376/1614 examples):
# Accuracy: 0.454
# F1: 0.385
# Precision: 0.546
# Recall: 0.454
#
# Intermediate Results (1408/1614 examples):
# Accuracy: 0.455
# F1: 0.386
# Precision: 0.549
# Recall: 0.455
#
# Intermediate Results (1440/1614 examples):
# Accuracy: 0.455
# F1: 0.385
# Precision: 0.549
# Recall: 0.455
#
# Intermediate Results (1472/1614 examples):
# Accuracy: 0.457
# F1: 0.386
# Precision: 0.551
# Recall: 0.457
#
# Intermediate Results (1504/1614 examples):
# Accuracy: 0.455
# F1: 0.384
# Precision: 0.548
# Recall: 0.455
#
# Intermediate Results (1536/1614 examples):
# Accuracy: 0.456
# F1: 0.385
# Precision: 0.549
# Recall: 0.456
#
# Intermediate Results (1568/1614 examples):
# Accuracy: 0.459
# F1: 0.389
# Precision: 0.551
# Recall: 0.459
#
# Intermediate Results (1600/1614 examples):
# Accuracy: 0.459
# F1: 0.389
# Precision: 0.549
# Recall: 0.459
#
# Final Results for ideology using text_en:
# Accuracy: 0.458
# F1: 0.389
# Precision: 0.550
# Recall: 0.458
#
# Processing ideology - text
#
# Intermediate Results (32/1614 examples):
# Accuracy: 0.312
# F1: 0.237
# Precision: 0.433
# Recall: 0.312
#
# Intermediate Results (64/1614 examples):
# Accuracy: 0.375
# F1: 0.297
# Precision: 0.413
# Recall: 0.375
#
# Intermediate Results (96/1614 examples):
# Accuracy: 0.469
# F1: 0.393
# Precision: 0.541
# Recall: 0.469
#
# Intermediate Results (128/1614 examples):
# Accuracy: 0.469
# F1: 0.393
# Precision: 0.559
# Recall: 0.469
#
# Intermediate Results (160/1614 examples):
# Accuracy: 0.438
# F1: 0.352
# Precision: 0.563
# Recall: 0.438
#
# Intermediate Results (192/1614 examples):
# Accuracy: 0.448
# F1: 0.365
# Precision: 0.557
# Recall: 0.448
#
# Intermediate Results (224/1614 examples):
# Accuracy: 0.442
# F1: 0.361
# Precision: 0.564
# Recall: 0.442
#
# Intermediate Results (256/1614 examples):
# Accuracy: 0.449
# F1: 0.367
# Precision: 0.586
# Recall: 0.449
#
# Intermediate Results (288/1614 examples):
# Accuracy: 0.462
# F1: 0.380
# Precision: 0.563
# Recall: 0.462
#
# Intermediate Results (320/1614 examples):
# Accuracy: 0.469
# F1: 0.387
# Precision: 0.556
# Recall: 0.469
#
# Intermediate Results (352/1614 examples):
# Accuracy: 0.460
# F1: 0.378
# Precision: 0.568
# Recall: 0.460
#
# Intermediate Results (384/1614 examples):
# Accuracy: 0.464
# F1: 0.385
# Precision: 0.561
# Recall: 0.464
#
# Intermediate Results (416/1614 examples):
# Accuracy: 0.459
# F1: 0.380
# Precision: 0.560
# Recall: 0.459
#
# Intermediate Results (448/1614 examples):
# Accuracy: 0.464
# F1: 0.384
# Precision: 0.572
# Recall: 0.464
#
# Intermediate Results (480/1614 examples):
# Accuracy: 0.450
# F1: 0.365
# Precision: 0.569
# Recall: 0.450
#
# Intermediate Results (512/1614 examples):
# Accuracy: 0.449
# F1: 0.365
# Precision: 0.572
# Recall: 0.449
#
# Intermediate Results (544/1614 examples):
# Accuracy: 0.449
# F1: 0.363
# Precision: 0.579
# Recall: 0.449
#
# Intermediate Results (576/1614 examples):
# Accuracy: 0.453
# F1: 0.368
# Precision: 0.588
# Recall: 0.453
#
# Intermediate Results (608/1614 examples):
# Accuracy: 0.446
# F1: 0.358
# Precision: 0.583
# Recall: 0.446
#
# Intermediate Results (640/1614 examples):
# Accuracy: 0.448
# F1: 0.362
# Precision: 0.571
# Recall: 0.448
#
# Intermediate Results (672/1614 examples):
# Accuracy: 0.442
# F1: 0.355
# Precision: 0.551
# Recall: 0.442
#
# Intermediate Results (704/1614 examples):
# Accuracy: 0.440
# F1: 0.352
# Precision: 0.554
# Recall: 0.440
#
# Intermediate Results (736/1614 examples):
# Accuracy: 0.443
# F1: 0.355
# Precision: 0.538
# Recall: 0.443
#
# Intermediate Results (768/1614 examples):
# Accuracy: 0.444
# F1: 0.357
# Precision: 0.538
# Recall: 0.444
#
# Intermediate Results (800/1614 examples):
# Accuracy: 0.443
# F1: 0.354
# Precision: 0.542
# Recall: 0.443
#
# Intermediate Results (832/1614 examples):
# Accuracy: 0.444
# F1: 0.354
# Precision: 0.541
# Recall: 0.444
#
# Intermediate Results (864/1614 examples):
# Accuracy: 0.448
# F1: 0.359
# Precision: 0.545
# Recall: 0.448
#
# Intermediate Results (896/1614 examples):
# Accuracy: 0.445
# F1: 0.357
# Precision: 0.543
# Recall: 0.445
#
# Intermediate Results (928/1614 examples):
# Accuracy: 0.444
# F1: 0.356
# Precision: 0.540
# Recall: 0.444
#
# Intermediate Results (960/1614 examples):
# Accuracy: 0.439
# F1: 0.349
# Precision: 0.535
# Recall: 0.439
#
# Intermediate Results (992/1614 examples):
# Accuracy: 0.439
# F1: 0.350
# Precision: 0.544
# Recall: 0.439
#
# Intermediate Results (1024/1614 examples):
# Accuracy: 0.435
# F1: 0.345
# Precision: 0.533
# Recall: 0.435
#
# Intermediate Results (1056/1614 examples):
# Accuracy: 0.438
# F1: 0.350
# Precision: 0.543
# Recall: 0.438
#
# Intermediate Results (1088/1614 examples):
# Accuracy: 0.438
# F1: 0.350
# Precision: 0.544
# Recall: 0.438
#
# Intermediate Results (1120/1614 examples):
# Accuracy: 0.442
# F1: 0.354
# Precision: 0.539
# Recall: 0.442
#
# Intermediate Results (1152/1614 examples):
# Accuracy: 0.444
# F1: 0.356
# Precision: 0.539
# Recall: 0.444
#
# Intermediate Results (1184/1614 examples):
# Accuracy: 0.444
# F1: 0.358
# Precision: 0.544
# Recall: 0.444
#
# Intermediate Results (1216/1614 examples):
# Accuracy: 0.443
# F1: 0.356
# Precision: 0.543
# Recall: 0.443
#
# Intermediate Results (1248/1614 examples):
# Accuracy: 0.446
# F1: 0.359
# Precision: 0.543
# Recall: 0.446
#
# Intermediate Results (1280/1614 examples):
# Accuracy: 0.442
# F1: 0.356
# Precision: 0.547
# Recall: 0.442
#
# Intermediate Results (1312/1614 examples):
# Accuracy: 0.444
# F1: 0.357
# Precision: 0.545
# Recall: 0.444
#
# Intermediate Results (1344/1614 examples):
# Accuracy: 0.444
# F1: 0.357
# Precision: 0.544
# Recall: 0.444
#
# Intermediate Results (1376/1614 examples):
# Accuracy: 0.445
# F1: 0.357
# Precision: 0.545
# Recall: 0.445
#
# Intermediate Results (1408/1614 examples):
# Accuracy: 0.445
# F1: 0.357
# Precision: 0.547
# Recall: 0.445
#
# Intermediate Results (1440/1614 examples):
# Accuracy: 0.444
# F1: 0.356
# Precision: 0.544
# Recall: 0.444
#
# Intermediate Results (1472/1614 examples):
# Accuracy: 0.446
# F1: 0.357
# Precision: 0.545
# Recall: 0.446
#
# Intermediate Results (1504/1614 examples):
# Accuracy: 0.446
# F1: 0.358
# Precision: 0.545
# Recall: 0.446
#
# Intermediate Results (1536/1614 examples):
# Accuracy: 0.447
# F1: 0.359
# Precision: 0.550
# Recall: 0.447
#
# Intermediate Results (1568/1614 examples):
# Accuracy: 0.448
# F1: 0.361
# Precision: 0.548
# Recall: 0.448
#
# Intermediate Results (1600/1614 examples):
# Accuracy: 0.451
# F1: 0.363
# Precision: 0.551
# Recall: 0.451
#
# Final Results for ideology using text:
# Accuracy: 0.450
# F1: 0.362
# Precision: 0.552
# Recall: 0.450
#
# Processing power - text_en
#
# Intermediate Results (32/1739 examples):
# Accuracy: 0.438
# F1: 0.383
# Precision: 0.652
# Recall: 0.438
#
# Intermediate Results (64/1739 examples):
# Accuracy: 0.391
# F1: 0.308
# Precision: 0.589
# Recall: 0.391
#
# Intermediate Results (96/1739 examples):
# Accuracy: 0.427
# F1: 0.326
# Precision: 0.614
# Recall: 0.427
#
# Intermediate Results (128/1739 examples):
# Accuracy: 0.453
# F1: 0.350
# Precision: 0.550
# Recall: 0.453
#
# Intermediate Results (160/1739 examples):
# Accuracy: 0.456
# F1: 0.355
# Precision: 0.495
# Recall: 0.456
#
# Intermediate Results (192/1739 examples):
# Accuracy: 0.458
# F1: 0.360
# Precision: 0.492
# Recall: 0.458
#
# Intermediate Results (224/1739 examples):
# Accuracy: 0.451
# F1: 0.356
# Precision: 0.509
# Recall: 0.451
#
# Intermediate Results (256/1739 examples):
# Accuracy: 0.449
# F1: 0.360
# Precision: 0.501
# Recall: 0.449
#
# Intermediate Results (288/1739 examples):
# Accuracy: 0.451
# F1: 0.359
# Precision: 0.500
# Recall: 0.451
#
# Intermediate Results (320/1739 examples):
# Accuracy: 0.463
# F1: 0.367
# Precision: 0.488
# Recall: 0.463
#
# Intermediate Results (352/1739 examples):
# Accuracy: 0.474
# F1: 0.384
# Precision: 0.525
# Recall: 0.474
#
# Intermediate Results (384/1739 examples):
# Accuracy: 0.477
# F1: 0.386
# Precision: 0.522
# Recall: 0.477
#
# Intermediate Results (416/1739 examples):
# Accuracy: 0.478
# F1: 0.391
# Precision: 0.493
# Recall: 0.478
#
# Intermediate Results (448/1739 examples):
# Accuracy: 0.482
# F1: 0.396
# Precision: 0.495
# Recall: 0.482
#
# Intermediate Results (480/1739 examples):
# Accuracy: 0.485
# F1: 0.398
# Precision: 0.505
# Recall: 0.485
#
# Intermediate Results (512/1739 examples):
# Accuracy: 0.479
# F1: 0.391
# Precision: 0.496
# Recall: 0.479
#
# Intermediate Results (544/1739 examples):
# Accuracy: 0.480
# F1: 0.395
# Precision: 0.496
# Recall: 0.480
#
# Intermediate Results (576/1739 examples):
# Accuracy: 0.483
# F1: 0.397
# Precision: 0.494
# Recall: 0.483
#
# Intermediate Results (608/1739 examples):
# Accuracy: 0.482
# F1: 0.400
# Precision: 0.490
# Recall: 0.482
#
# Intermediate Results (640/1739 examples):
# Accuracy: 0.486
# F1: 0.405
# Precision: 0.498
# Recall: 0.486
#
# Intermediate Results (672/1739 examples):
# Accuracy: 0.488
# F1: 0.406
# Precision: 0.501
# Recall: 0.488
#
# Intermediate Results (704/1739 examples):
# Accuracy: 0.491
# F1: 0.410
# Precision: 0.511
# Recall: 0.491
#
# Intermediate Results (736/1739 examples):
# Accuracy: 0.489
# F1: 0.407
# Precision: 0.511
# Recall: 0.489
#
# Intermediate Results (768/1739 examples):
# Accuracy: 0.488
# F1: 0.408
# Precision: 0.505
# Recall: 0.488
#
# Intermediate Results (800/1739 examples):
# Accuracy: 0.487
# F1: 0.406
# Precision: 0.502
# Recall: 0.487
#
# Intermediate Results (832/1739 examples):
# Accuracy: 0.484
# F1: 0.403
# Precision: 0.498
# Recall: 0.484
#
# Intermediate Results (864/1739 examples):
# Accuracy: 0.483
# F1: 0.402
# Precision: 0.499
# Recall: 0.483
#
# Intermediate Results (896/1739 examples):
# Accuracy: 0.481
# F1: 0.401
# Precision: 0.495
# Recall: 0.481
#
# Intermediate Results (928/1739 examples):
# Accuracy: 0.487
# F1: 0.406
# Precision: 0.502
# Recall: 0.487
#
# Intermediate Results (960/1739 examples):
# Accuracy: 0.482
# F1: 0.401
# Precision: 0.494
# Recall: 0.482
#
# Intermediate Results (992/1739 examples):
# Accuracy: 0.481
# F1: 0.399
# Precision: 0.491
# Recall: 0.481
#
# Intermediate Results (1024/1739 examples):
# Accuracy: 0.481
# F1: 0.400
# Precision: 0.491
# Recall: 0.481
#
# Intermediate Results (1056/1739 examples):
# Accuracy: 0.476
# F1: 0.394
# Precision: 0.484
# Recall: 0.476
#
# Intermediate Results (1088/1739 examples):
# Accuracy: 0.476
# F1: 0.394
# Precision: 0.487
# Recall: 0.476
#
# Intermediate Results (1120/1739 examples):
# Accuracy: 0.479
# F1: 0.397
# Precision: 0.488
# Recall: 0.479
#
# Intermediate Results (1152/1739 examples):
# Accuracy: 0.485
# F1: 0.403
# Precision: 0.493
# Recall: 0.485
#
# Intermediate Results (1184/1739 examples):
# Accuracy: 0.486
# F1: 0.403
# Precision: 0.492
# Recall: 0.486
#
# Intermediate Results (1216/1739 examples):
# Accuracy: 0.485
# F1: 0.403
# Precision: 0.490
# Recall: 0.485
#
# Intermediate Results (1248/1739 examples):
# Accuracy: 0.482
# F1: 0.400
# Precision: 0.486
# Recall: 0.482
#
# Intermediate Results (1280/1739 examples):
# Accuracy: 0.480
# F1: 0.399
# Precision: 0.486
# Recall: 0.480
#
# Intermediate Results (1312/1739 examples):
# Accuracy: 0.480
# F1: 0.399
# Precision: 0.481
# Recall: 0.480
#
# Intermediate Results (1344/1739 examples):
# Accuracy: 0.480
# F1: 0.400
# Precision: 0.484
# Recall: 0.480
#
# Intermediate Results (1376/1739 examples):
# Accuracy: 0.480
# F1: 0.399
# Precision: 0.483
# Recall: 0.480
#
# Intermediate Results (1408/1739 examples):
# Accuracy: 0.482
# F1: 0.400
# Precision: 0.487
# Recall: 0.482
#
# Intermediate Results (1440/1739 examples):
# Accuracy: 0.485
# F1: 0.404
# Precision: 0.488
# Recall: 0.485
#
# Intermediate Results (1472/1739 examples):
# Accuracy: 0.488
# F1: 0.406
# Precision: 0.491
# Recall: 0.488
#
# Intermediate Results (1504/1739 examples):
# Accuracy: 0.491
# F1: 0.408
# Precision: 0.494
# Recall: 0.491
#
# Intermediate Results (1536/1739 examples):
# Accuracy: 0.491
# F1: 0.407
# Precision: 0.494
# Recall: 0.491
#
# Intermediate Results (1568/1739 examples):
# Accuracy: 0.492
# F1: 0.409
# Precision: 0.498
# Recall: 0.492
#
# Intermediate Results (1600/1739 examples):
# Accuracy: 0.491
# F1: 0.408
# Precision: 0.500
# Recall: 0.491
#
# Intermediate Results (1632/1739 examples):
# Accuracy: 0.493
# F1: 0.412
# Precision: 0.503
# Recall: 0.493
#
# Intermediate Results (1664/1739 examples):
# Accuracy: 0.495
# F1: 0.414
# Precision: 0.506
# Recall: 0.495
#
# Intermediate Results (1696/1739 examples):
# Accuracy: 0.494
# F1: 0.414
# Precision: 0.510
# Recall: 0.494
#
# Intermediate Results (1728/1739 examples):
# Accuracy: 0.493
# F1: 0.413
# Precision: 0.509
# Recall: 0.493
#
# Final Results for power using text_en:
# Accuracy: 0.495
# F1: 0.415
# Precision: 0.512
# Recall: 0.495
#
# Processing power - text
#
# Intermediate Results (32/1739 examples):
# Accuracy: 0.344
# F1: 0.225
# Precision: 0.443
# Recall: 0.344
#
# Intermediate Results (64/1739 examples):
# Accuracy: 0.344
# F1: 0.202
# Precision: 0.445
# Recall: 0.344
#
# Intermediate Results (96/1739 examples):
# Accuracy: 0.365
# F1: 0.223
# Precision: 0.296
# Recall: 0.365
#
# Intermediate Results (128/1739 examples):
# Accuracy: 0.414
# F1: 0.276
# Precision: 0.370
# Recall: 0.414
#
# Intermediate Results (160/1739 examples):
# Accuracy: 0.425
# F1: 0.288
# Precision: 0.333
# Recall: 0.425
#
# Intermediate Results (192/1739 examples):
# Accuracy: 0.427
# F1: 0.288
# Precision: 0.320
# Recall: 0.427
#
# Intermediate Results (224/1739 examples):
# Accuracy: 0.420
# F1: 0.287
# Precision: 0.373
# Recall: 0.420
#
# Intermediate Results (256/1739 examples):
# Accuracy: 0.422
# F1: 0.296
# Precision: 0.397
# Recall: 0.422
#
# Intermediate Results (288/1739 examples):
# Accuracy: 0.420
# F1: 0.293
# Precision: 0.374
# Recall: 0.420
#
# Intermediate Results (320/1739 examples):
# Accuracy: 0.441
# F1: 0.310
# Precision: 0.386
# Recall: 0.441
#
# Intermediate Results (352/1739 examples):
# Accuracy: 0.440
# F1: 0.311
# Precision: 0.394
# Recall: 0.440
#
# Intermediate Results (384/1739 examples):
# Accuracy: 0.440
# F1: 0.310
# Precision: 0.378
# Recall: 0.440
#
# Intermediate Results (416/1739 examples):
# Accuracy: 0.459
# F1: 0.330
# Precision: 0.404
# Recall: 0.459
#
# Intermediate Results (448/1739 examples):
# Accuracy: 0.467
# F1: 0.340
# Precision: 0.426
# Recall: 0.467
#
# Intermediate Results (480/1739 examples):
# Accuracy: 0.467
# F1: 0.343
# Precision: 0.434
# Recall: 0.467
#
# Intermediate Results (512/1739 examples):
# Accuracy: 0.463
# F1: 0.342
# Precision: 0.438
# Recall: 0.463
#
# Intermediate Results (544/1739 examples):
# Accuracy: 0.467
# F1: 0.348
# Precision: 0.450
# Recall: 0.467
#
# Intermediate Results (576/1739 examples):
# Accuracy: 0.476
# F1: 0.358
# Precision: 0.469
# Recall: 0.476
#
# Intermediate Results (608/1739 examples):
# Accuracy: 0.474
# F1: 0.357
# Precision: 0.458
# Recall: 0.474
#
# Intermediate Results (640/1739 examples):
# Accuracy: 0.475
# F1: 0.358
# Precision: 0.460
# Recall: 0.475
#
# Intermediate Results (672/1739 examples):
# Accuracy: 0.476
# F1: 0.361
# Precision: 0.463
# Recall: 0.476
#
# Intermediate Results (704/1739 examples):
# Accuracy: 0.474
# F1: 0.360
# Precision: 0.459
# Recall: 0.474
#
# Intermediate Results (736/1739 examples):
# Accuracy: 0.473
# F1: 0.359
# Precision: 0.464
# Recall: 0.473
#
# Intermediate Results (768/1739 examples):
# Accuracy: 0.473
# F1: 0.358
# Precision: 0.456
# Recall: 0.473
#
# Intermediate Results (800/1739 examples):
# Accuracy: 0.475
# F1: 0.361
# Precision: 0.463
# Recall: 0.475
#
# Intermediate Results (832/1739 examples):
# Accuracy: 0.475
# F1: 0.360
# Precision: 0.467
# Recall: 0.475
#
# Intermediate Results (864/1739 examples):
# Accuracy: 0.473
# F1: 0.360
# Precision: 0.471
# Recall: 0.473
#
# Intermediate Results (896/1739 examples):
# Accuracy: 0.471
# F1: 0.356
# Precision: 0.463
# Recall: 0.471
#
# Intermediate Results (928/1739 examples):
# Accuracy: 0.473
# F1: 0.360
# Precision: 0.459
# Recall: 0.473
#
# Intermediate Results (960/1739 examples):
# Accuracy: 0.472
# F1: 0.357
# Precision: 0.458
# Recall: 0.472
#
# Intermediate Results (992/1739 examples):
# Accuracy: 0.475
# F1: 0.361
# Precision: 0.470
# Recall: 0.475
#
# Intermediate Results (1024/1739 examples):
# Accuracy: 0.473
# F1: 0.358
# Precision: 0.460
# Recall: 0.473
#
# Intermediate Results (1056/1739 examples):
# Accuracy: 0.470
# F1: 0.354
# Precision: 0.456
# Recall: 0.470
#
# Intermediate Results (1088/1739 examples):
# Accuracy: 0.470
# F1: 0.354
# Precision: 0.463
# Recall: 0.470
#
# Intermediate Results (1120/1739 examples):
# Accuracy: 0.472
# F1: 0.356
# Precision: 0.464
# Recall: 0.472
#
# Intermediate Results (1152/1739 examples):
# Accuracy: 0.478
# F1: 0.363
# Precision: 0.469
# Recall: 0.478
#
# Intermediate Results (1184/1739 examples):
# Accuracy: 0.478
# F1: 0.363
# Precision: 0.463
# Recall: 0.478
#
# Intermediate Results (1216/1739 examples):
# Accuracy: 0.478
# F1: 0.363
# Precision: 0.461
# Recall: 0.478
#
# Intermediate Results (1248/1739 examples):
# Accuracy: 0.476
# F1: 0.361
# Precision: 0.461
# Recall: 0.476
#
# Intermediate Results (1280/1739 examples):
# Accuracy: 0.473
# F1: 0.357
# Precision: 0.457
# Recall: 0.473
#
# Intermediate Results (1312/1739 examples):
# Accuracy: 0.477
# F1: 0.361
# Precision: 0.462
# Recall: 0.477
#
# Intermediate Results (1344/1739 examples):
# Accuracy: 0.475
# F1: 0.358
# Precision: 0.459
# Recall: 0.475
#
# Intermediate Results (1376/1739 examples):
# Accuracy: 0.479
# F1: 0.365
# Precision: 0.472
# Recall: 0.479
#
# Intermediate Results (1408/1739 examples):
# Accuracy: 0.479
# F1: 0.364
# Precision: 0.475
# Recall: 0.479
#
# Intermediate Results (1440/1739 examples):
# Accuracy: 0.484
# F1: 0.370
# Precision: 0.480
# Recall: 0.484
#
# Intermediate Results (1472/1739 examples):
# Accuracy: 0.487
# F1: 0.374
# Precision: 0.484
# Recall: 0.487
#
# Intermediate Results (1504/1739 examples):
# Accuracy: 0.489
# F1: 0.376
# Precision: 0.485
# Recall: 0.489
#
# Intermediate Results (1536/1739 examples):
# Accuracy: 0.488
# F1: 0.374
# Precision: 0.481
# Recall: 0.488
#
# Intermediate Results (1568/1739 examples):
# Accuracy: 0.488
# F1: 0.375
# Precision: 0.485
# Recall: 0.488
#
# Intermediate Results (1600/1739 examples):
# Accuracy: 0.486
# F1: 0.372
# Precision: 0.486
# Recall: 0.486
#
# Intermediate Results (1632/1739 examples):
# Accuracy: 0.488
# F1: 0.374
# Precision: 0.492
# Recall: 0.488
#
# Intermediate Results (1664/1739 examples):
# Accuracy: 0.490
# F1: 0.378
# Precision: 0.499
# Recall: 0.490
#
# Intermediate Results (1696/1739 examples):
# Accuracy: 0.486
# F1: 0.373
# Precision: 0.495
# Recall: 0.486
#
# Intermediate Results (1728/1739 examples):
# Accuracy: 0.486
# F1: 0.372
# Precision: 0.495
# Recall: 0.486
#
# Final Results for power using text:
# Accuracy: 0.487
# F1: 0.373
# Precision: 0.497
# Recall: 0.487
